# %%
import geopandas as gpd
import pylab as pl
import pandas as pd
import shapely
# %pylab inline

# !wget -nc https://files.datapress.com/london/dataset/london-schools-atlas/2017-01-26T18:50:00/all_schools_xy_2016.csv


df = pd.read_csv('all_schools_xy_2016.csv')
primary_coords = df[df.Primary == 1][["x", "y"]]
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df.head()
# Out:
#   OBJECTID     URN                                         SCHOOL_NAM  \
# 0        1  135155                        Ayesha Siddiqa Girls School
# 1        2  140492                                 Beis Medrash Elyon
# 2        3  141411                    Big Creative Independent School
# 3        4  142336                             Wetherby Senior School
# 4        5  100042  St Mary's Kilburn Church of England Primary Sc...
#
#                        TYPE           PHASE                   ADDRESS  \
# 0  Other Independent School  Not applicable      165-169 The Broadway
# 1  Other Independent School  Not applicable  233 West Hendon Broadway
# 2  Other Independent School  Not applicable        Silver Birch House
# 3  Other Independent School  Not applicable       100 Marylebone Lane
# 4    Voluntary Aided School         Primary                 Quex Road
#
#           TOWN POSTCODE STATUS GENDER    ...             LA_NAME  \
# 0     Southall  UB1 1LR   Open  Girls    ...              Ealing
# 1       London  NW9 7DG   Open   Boys    ...              Barnet
# 2  Walthamstow  E17 5SD   Open  Mixed    ...      Waltham Forest
# 3       London  W1U 2QB   Open   Boys    ...         Westminster
# 4       London  NW6 4PG   Open  Mixed    ...              Camden
#
#                                    WEBLINK      AGE   map_icon NEW_URN  \
# 0                                            19-Nov
# 1                                            16-Nov
# 2                                           15 - 16
# 3                                            16-Nov
# 4  http://www.stmarykilburn.camden.sch.uk/   11-Mar  VOLUNTARY
#
#   OLD_URN map_icon_l Primary         x          y
# 0                  2       0 -0.378496  51.507500
# 1                  2       0 -0.241628  51.578999
# 2                  2       0 -0.042590  51.594002
# 3                  2       0 -0.150409  51.517601
# 4                  2       1 -0.193367  51.540402
#
# [5 rows x 24 columns]
